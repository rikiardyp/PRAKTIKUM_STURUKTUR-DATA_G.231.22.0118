# %% [markdown]
# **selectionSort**

# %%
def selectionSort(alist):
 for slot in range(0,len(alist)-1):
  position=slot
  for location in range(slot+1,len(alist)):
    if alist[location]<alist[position]:
      position = location

  temp = alist[slot]
  alist[slot] = alist[position]
  alist[position] = temp
  print(alist)
angka = [5,1,4,2,8,10,3]
selectionSort(angka)
print(angka)
# Out:
# [1, 5, 4, 2, 8, 10, 3]
# [1, 2, 4, 5, 8, 10, 3]
# [1, 2, 3, 5, 8, 10, 4]
# [1, 2, 3, 4, 8, 10, 5]
# [1, 2, 3, 4, 5, 10, 8]
# [1, 2, 3, 4, 5, 8, 10]
# [1, 2, 3, 4, 5, 8, 10]

# %% [markdown]
# **Tuple**

# %%
data = ("Python","Struktur Data", "Smstr 3")
print(data)
# Out:
# ('Python', 'Struktur Data', 'Smstr 3')

# %% [markdown]
# **Dictionary**

# %%
dict = {'Name': 'Riki', 'Age': 17, 'Class': 'First'}
print ("dict['Name']: ", dict['Name'])
print ("dict['Age']: ", dict['Age'])
# Out:
# dict['Name']:  Riki
# dict['Age']:  17
